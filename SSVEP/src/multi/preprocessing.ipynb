# %%
import numpy as np
from scipy.fft import fft
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy.signal import stft, resample, welch
from scipy.fft import fft, ifft
from scipy import signal
from copy import deepcopy as dc
from sklearn.preprocessing import LabelEncoder
import mne

FS = 512

# %%
data = np.load('../../datasets/avi/multi/data_multi.npy')
label = np.load('../../datasets/avi/multi/labels_multi.npy')

X = data.swapaxes(1, 0)

data.shape, label.shape
# Out:
# ((80, 8192), (80,))

# %%
w = fft(data)
w.shape
# Out:
# (80, 8192)

# %%
def print_graphs(data):
    for i in range(data.shape[0]):
        plt.plot(data[i,:])
    plt.title('Domínio do tempo')
    plt.show()

    for i in range(data.shape[0]):
        plt.psd(data[i,:], Fs=FS)
    plt.title('Domínio da frequência')
    plt.show()
    
    for i in range(data.shape[0]):
        plt.specgram(data[i,:], Fs=FS)
    plt.title('Espectrograma')
    plt.show()

# %%
rcParams['figure.figsize'] = [15., 5.]
print_graphs(data[:1,:])

# %%
ch = 1
freqSp = FS
ch_name = ['Oz']
ch_type = ['eeg']

info = mne.create_info(ch_name, sfreq=freqSp, ch_types=ch_type)
info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Oz
#  chs: 1 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 256.0 Hz
#  meas_date: unspecified
#  nchan: 1
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
data_correct = data.reshape(data.shape[0], 1, data.shape[1])
# método para transformar labels categóricos
le = LabelEncoder()
events = np.column_stack((
    np.array(range(len(label))),
    np.zeros(label.shape[0], dtype=int),
    le.fit_transform(label))
)
event_dict = {'6':0, '6.5':1, '7':2, '7.5':3, '8.2':4, '9.3':5}
mne_data = mne.EpochsArray(data_correct, info, events, event_id=event_dict)
mne_data
# Out:
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsArray |  80 events (all good), 0 – 15.998 s, baseline off, ~5.0 MB, data loaded,
#  '6': 32
#  '6.5': 4
#  '7': 8
#  '7.5': 12
#  '8.2': 20
#  '9.3': 4>

# %%
mne_data.plot_psd(fmin=4, fmax=12, average=True, spatial_colors=False)

# %%
def butter_bandpass(data, lowcut, highcut, fs=FS, order=4):
    nyq = fs * 0.5
    low = lowcut / nyq
    high = highcut / nyq
    b, a = signal.butter(order, [low, high], btype='bandpass')
    return signal.filtfilt(b, a, data)


def butter_lowpass(data, lowcut, fs=FS, order=4):
    nyq = fs * 0.5
    low = lowcut / nyq
    b, a = signal.butter(order, low, btype='lowpass')
    return signal.filtfilt(b, a, data)


def butter_highpass(data, highcut, fs=FS, order=4):
    nyq = fs * 0.5
    high = highcut / nyq
    b, a = signal.butter(order, high, btype='highpass')
    return signal.filtfilt(b, a, data)


def butter_notch(data, cutoff, var=1, fs=FS, order=4):
    nyq = fs * 0.5
    low = (cutoff - var) / nyq
    high = (cutoff + var) / nyq
    b, a = signal.iirfilter(order, [low, high], btype='bandstop', ftype="butter")
    return signal.filtfilt(b, a, data)

# %%
X_f = dc(X)
X_f = butter_notch(X_f, 60)
X_f = butter_notch(X_f, 120)
print_graphs(X_f[:1,:])
# Out:
# C:\Users\vinny\AppData\Local\Temp\ipykernel_12228\4284849796.py:13: UserWarning: Only one segment is calculated since parameter NFFT (=256) >= signal length (=80).
#   plt.specgram(data[i,:], Fs=FS)

# %%
X_f = dc(X)
X_f = butter_bandpass(X_f, 3., 35.)
print_graphs(X_f[:1,:])
# Out:
# C:\Users\vinny\AppData\Local\Temp\ipykernel_12228\4284849796.py:13: UserWarning: Only one segment is calculated since parameter NFFT (=256) >= signal length (=80).
#   plt.specgram(data[i,:], Fs=FS)

# %%
X_f = dc(X)
X_f = butter_notch(X_f, 60)
X_f = butter_notch(X_f, 120)
X_f = butter_lowpass(X_f, 50.)
X_f = butter_highpass(X_f, 3.)
print_graphs(X_f[:1,:])
np.save("datasets/OpenBCI_GUI-v5-meditation_filtered.npy", X_f)
# Out:
# C:\Users\vinny\AppData\Local\Temp\ipykernel_12228\4284849796.py:13: UserWarning: Only one segment is calculated since parameter NFFT (=256) >= signal length (=80).
#   plt.specgram(data[i,:], Fs=FS)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\vinny\OneDrive\Documentos\UTFPR\Reconhecimento de Padroes\tutoriais\SSVEP\src\preprocessing.ipynb Cell 11 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/vinny/OneDrive/Documentos/UTFPR/Reconhecimento%20de%20Padroes/tutoriais/SSVEP/src/preprocessing.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> X_f = butter_highpass(X_f, 3.)
#       <a href='vscode-notebook-cell:/c%3A/Users/vinny/OneDrive/Documentos/UTFPR/Reconhecimento%20de%20Padroes/tutoriais/SSVEP/src/preprocessing.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> print_graphs(X_f[:1,:])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vinny/OneDrive/Documentos/UTFPR/Reconhecimento%20de%20Padroes/tutoriais/SSVEP/src/preprocessing.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> np.save("datasets/OpenBCI_GUI-v5-meditation_filtered.npy", X_f)
#
# File <__array_function__ internals>:180, in save(*args, **kwargs)
#
# File c:\Users\vinny\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:498, in save(file, arr, allow_pickle, fix_imports)
#     496     if not file.endswith('.npy'):
#     497         file = file + '.npy'
# --> 498     file_ctx = open(file, "wb")
#     500 with file_ctx as fid:
#     501     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/OpenBCI_GUI-v5-meditation_filtered.npy'
